# %% [markdown]
# <a href="https://colab.research.google.com/github/PraneethaBalanagu/Sync2Lip-Lip-sync-video-generation/blob/main/Lip_Sync_using_DINET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Check gpu
# !nvidia-smi
# Out:
# Sun Aug  6 18:38:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title Download DINet
# !git clone https://github.com/MRzzm/DINet
# %cd /content/DINet
# Out:
# Cloning into 'DINet'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 43 (delta 8), reused 6 (delta 6), pack-reused 23 (from 1)
# Receiving objects: 100% (43/43), 39.03 KiB | 9.76 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/DINet

# %%
#@title Download model and data
# !gdown --id 1CKUlFdvVtH-f2BYlQbjqfkoRlC_7C0Ka
# !unzip -o asserts.zip
# !rm asserts.zip
# !rm asserts.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1CKUlFdvVtH-f2BYlQbjqfkoRlC_7C0Ka
# From (redirected): https://drive.google.com/uc?id=1CKUlFdvVtH-f2BYlQbjqfkoRlC_7C0Ka&confirm=t&uuid=968b425c-df83-480b-9825-bd5267e73392
# To: /content/DINet/asserts.zip
# 100% 1.01G/1.01G [00:25<00:00, 39.5MB/s]
# Archive:  asserts.zip
#    creating: asserts/
#   inflating: asserts/clip_training_DINet_256mouth.pth
#    creating: asserts/examples/
#   inflating: asserts/examples/driving_audio_1.wav
#   inflating: asserts/examples/driving_audio_2.wav
#   inflating: asserts/examples/driving_audio_3.wav
#   inflating: asserts/examples/driving_audio_4.wav
#   inflating: asserts/examples/driving_audio_5.wav
#   inflating: asserts/examples/driving_audio_6.wav
#   inflating: asserts/examples/test1.csv
#   inflating: asserts/examples/test1.mp4
#   inflating: asserts/examples/test10.csv
#   inflating: asserts/examples/test10.mp4
#   inflating: asserts/examples/test11.csv
#   inflating: asserts/examples/test11.mp4
#   inflating: asserts/examples/test12.csv
#   inflating: asserts/examples/test12.mp4
#   inflating: asserts/examples/test13.csv
#   inflating: asserts/examples/test13.mp4
#   inflating: asserts/examples/test14.csv
#   inflating: asserts/examples/test14.mp4
#   inflating: asserts/examples/test15.csv
#   inflating: asserts/examples/test15.mp4
#   inflating: asserts/examples/test16.csv
#   inflating: asserts/examples/test16.mp4
#   inflating: asserts/examples/test17.csv
#   inflating: asserts/examples/test17.mp4
#   inflating: asserts/examples/test18.csv
#   inflating: asserts/examples/test18.mp4
#   inflating: asserts/examples/test19.csv
#   inflating: asserts/examples/test19.mp4
#   inflating: asserts/examples/test2.csv
#   inflating: asserts/examples/test2.mp4
#   inflating: asserts/examples/test20.csv
#   inflating: asserts/examples/test20.mp4
#   inflating: asserts/examples/test21.csv
#   inflating: asserts/examples/test21.mp4
#   inflating: asserts/examples/test22.csv
#   inflating: asserts/examples/test22.mp4
#   inflating: asserts/examples/test23.csv
#   inflating: asserts/examples/test23.mp4
#   inflating: asserts/examples/test24.csv
#   inflating: asserts/examples/test24.mp4
#   inflating: asserts/examples/test25.csv
#   inflating: asserts/examples/test25.mp4
#   inflating: asserts/examples/test26.csv
#   inflating: asserts/examples/test26.mp4
#   inflating: asserts/examples/test27.csv
#   inflating: asserts/examples/test27.mp4
#   inflating: asserts/examples/test3.csv
#   inflating: asserts/examples/test3.mp4
#   inflating: asserts/examples/test4.csv
#   inflating: asserts/examples/test4.mp4
#   inflating: asserts/examples/test5.csv
#   inflating: asserts/examples/test5.mp4
#   inflating: asserts/examples/test6.csv
#   inflating: asserts/examples/test6.mp4
#   inflating: asserts/examples/test7.csv
#   inflating: asserts/examples/test7.mp4
#   inflating: asserts/examples/test8.csv
#   inflating: asserts/examples/test8.mp4
#   inflating: asserts/examples/test9.csv
#   inflating: asserts/examples/test9.mp4
#   inflating: asserts/output_graph.pb
#   inflating: asserts/syncnet_128mouth.pth
#   inflating: asserts/syncnet_256mouth.pth
#   inflating: asserts/syncnet_64mouth.pth
#    creating: asserts/training_data/
#    creating: asserts/training_data/split_video_25fps/
#   inflating: asserts/training_data/split_video_25fps/BobCorker_0.mp4
#   inflating: asserts/training_data/split_video_25fps/KevinMcCarthy0_1.mp4
#    creating: asserts/training_data/split_video_25fps_landmark_openface/
#   inflating: asserts/training_data/split_video_25fps_landmark_openface/BobCorker_0.csv
#   inflating: asserts/training_data/split_video_25fps_landmark_openface/KevinMcCarthy0_1.csv
#    creating: asserts/training_model_weight/
#   inflating: asserts/training_video_name.txt
# rm: cannot remove 'asserts.zip': No such file or directory

# %%
#@title Install Virtual Environment
# miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages/')
# !conda install python=3.7 -y
# !python --version
# !conda create --name DINet python=3.7 -y
# !source activate DINet
# Out:
# --2025-01-23 04:34:49--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  37.5MB/s    in 2.2s
#
# 2025-01-23 04:34:52 (37.5 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 25.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         155 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2024.12.31-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2019.11.2~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1w-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2024 | 128 KB    | : 100% 1.0/1 [00:00<00:00,  6.72it/s]
# openssl-1.1.1w       | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.71it/s]
# certifi-2020.6.20    | 155 KB    | : 100% 1.0/1 [00:00<00:00,  7.61it/s]
# done
# done
# done
# Python 3.7.6
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 25.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/DINet
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     ------------------------------------------------------------
#                                            Total:        66.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.12.31-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1w-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.16-h7a1cb2a_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.38.4-py37h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages
# pip-22.3.1           | 2.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.41it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00,  7.05it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00,  6.64it/s]
# xz-5.4.6             | 643 KB    | : 100% 1.0/1 [00:00<00:00,  5.81it/s]
# python-3.7.16        | 44.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
# libffi-3.4.4         | 141 KB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
# tk-8.6.14            | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
# readline-8.2         | 357 KB    | : 100% 1.0/1 [00:00<00:00,  6.47it/s]
# setuptools-65.6.3    | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.19it/s]
# ncurses-6.4          | 914 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# wheel-0.38.4         | 63 KB     | : 100% 1.0/1 [00:00<00:00,  6.15it/s]
# ld_impl_linux-64-2.4 | 710 KB    | : 100% 1.0/1 [00:00<00:00,  5.54it/s]
# zlib-1.2.13          | 111 KB    | : 100% 1.0/1 [00:00<00:00,  7.08it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00,  6.99it/s]
# sqlite-3.45.3        | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.59it/s]
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate DINet
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
#@title Installation dependencies
# !pip install  resampy==0.2.2  python_speech_features  opencv_python==3.4.18.65
# !pip install  numpy===1.18.0  resampy==0.2.2      scipy==1.5.4
# !pip install  torch==1.7.1   torchvision==0.8.2    protobuf==3.20.0
# !pip install  tensorflow==1.15.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Collecting resampy==0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 17.2 MB/s
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
# Collecting opencv_python==3.4.18.65
#   Downloading opencv_python-3.4.18.65-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (58.4 MB)
#      |████████████████████████████████| 58.4 MB 59.9 MB/s
# Collecting numpy>=1.10
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 29.6 MB/s
# Collecting scipy>=0.13
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting numba>=0.32
#   Downloading numba-0.56.4-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 20.2 MB/s
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/site-packages (from resampy==0.2.2) (1.14.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 263 kB/s
# Collecting importlib-metadata; python_version < "3.9"
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from numba>=0.32->resampy==0.2.2) (45.2.0.post20200210)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Building wheels for collected packages: resampy, python-speech-features
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320720 sha256=3bd28ebf8d7f477c48954385189520b01d847ccf54fd3ec53494519837a9e3ca
#   Stored in directory: /root/.cache/pip/wheels/a0/18/0a/8ad18a597d8333a142c9789338a96a6208f1198d290ece356c
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=0e75db5a5a444df221983ec1643450b7bd65ef7ef41750bf6e4643c3d04aabd1
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built resampy python-speech-features
# Installing collected packages: numpy, scipy, llvmlite, zipp, typing-extensions, importlib-metadata, numba, resampy, python-speech-features, opencv-python
# Successfully installed importlib-metadata-6.7.0 llvmlite-0.39.1 numba-0.56.4 numpy-1.21.6 opencv-python-3.4.18.65 python-speech-features-0.6 resampy-0.2.2 scipy-1.7.3 typing-extensions-4.7.1 zipp-3.15.0
# Collecting numpy===1.18.0
#   Downloading numpy-1.18.0-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.3 MB/s
# Requirement already satisfied: resampy==0.2.2 in /usr/local/lib/python3.7/site-packages (0.2.2)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 1.3 MB/s
# Requirement already satisfied: numba>=0.32 in /usr/local/lib/python3.7/site-packages (from resampy==0.2.2) (0.56.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/site-packages (from resampy==0.2.2) (1.14.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/site-packages (from numba>=0.32->resampy==0.2.2) (0.39.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /usr/local/lib/python3.7/site-packages (from numba>=0.32->resampy==0.2.2) (6.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from numba>=0.32->resampy==0.2.2) (45.2.0.post20200210)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.9"->numba>=0.32->resampy==0.2.2) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.9"->numba>=0.32->resampy==0.2.2) (4.7.1)
# Installing collected packages: numpy, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed numpy-1.18.0 scipy-1.5.4
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (776.8 MB)
#      |████████████████████████████████| 776.8 MB 13 kB/s
# Collecting torchvision==0.8.2
#   Downloading torchvision-0.8.2-cp37-cp37m-manylinux1_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 69 kB/s
# Collecting protobuf==3.20.0
#   Downloading protobuf-3.20.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 18.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/site-packages (from torch==1.7.1) (4.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from torch==1.7.1) (1.18.0)
# Collecting pillow>=4.1.1
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 45.2 MB/s
# Installing collected packages: torch, pillow, torchvision, protobuf
# Successfully installed pillow-9.5.0 protobuf-3.20.0 torch-1.7.1 torchvision-0.8.2
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting tensorflow==1.15.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5b/81/84fb7a323f9723f81edfc796d89e89aa95a9446ed7353c144195b3a3a3ba/tensorflow-1.15.2-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 37 kB/s
# Collecting grpcio>=1.8.6
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/90/f8/ffc848081d7c66ded9ed0743c1ad0140c70e45861566607889eb8fa1c098/grpcio-1.62.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 20.3 MB/s
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow==1.15.2) (0.34.2)
# Collecting astor>=0.6.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting keras-applications>=1.0.8
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.0 MB/s
# Collecting opt-einsum>=2.3.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 4.2 MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/site-packages (from tensorflow==1.15.2) (3.20.0)
# Collecting termcolor>=1.1.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/67/e1/434566ffce04448192369c1a282931cf4ae593e91907558eaecd2e9f2801/termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting google-pasta>=0.1.6
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.4 MB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/site-packages (from tensorflow==1.15.2) (1.18.0)
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.7 MB/s
# Collecting absl-py>=0.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 19.6 MB/s
# Collecting wrapt>=1.11.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7f/46/896369f2550d1ecb5e776f532aada5e77e5e13f821045978cf3d7f3f236b/wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/site-packages (from tensorflow==1.15.2) (1.14.0)
# Collecting gast==0.2.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz (10 kB)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 21.3 MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 19.8 MB/s
# Collecting h5py
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/95/be/de1e591bec008ed92d3829b985757b8bc2d34179feef5e181530876a4f9d/h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 18.7 MB/s
# Collecting werkzeug>=0.11.15
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f6/f8/9da63c1617ae2a1dec2fbf6412f3a0cfe9d4ce029eccbda6e1e4258ca45f/Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 19.4 MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (45.2.0.post20200210)
# Collecting markdown>=2.6.8
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1a/b5/228c1cdcfe138f1a8e01ab1b54284c8b83735476cb22b6ba251656ed13ad/Markdown-3.4.4-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Collecting MarkupSafe>=2.1.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4a/1d/c4f5016f87ced614eacc7d5fb85b25bcc0ff53e8f058d069fc8cbfdc3c7a/MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (6.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (4.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.15.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7539 sha256=67b7d953445f8611cbcd4d75341a6f5f0cf9940c57c2d99c9cae02b771e7c4f1
#   Stored in directory: /root/.cache/pip/wheels/cc/0e/83/9f24c5972affa5a98636935d34edb987be537aba9f10e43d4b
# Successfully built gast
# Installing collected packages: grpcio, astor, h5py, keras-applications, opt-einsum, termcolor, google-pasta, keras-preprocessing, absl-py, wrapt, gast, tensorflow-estimator, MarkupSafe, werkzeug, markdown, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astor-0.8.1 gast-0.2.2 google-pasta-0.2.0 grpcio-1.62.3 h5py-3.8.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.4.4 opt-einsum-3.3.0 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1 termcolor-2.3.0 werkzeug-2.2.3 wrapt-1.16.0

# %%
#@title Official Inference
# %cd /content/DINet
# !python inference.py --mouth_region_size=256 --source_video_path=/content/kimk_7s_raw.mp4 --source_openface_landmark_path=/content/kimk_7s_raw.csv --driving_audio_path=./asserts/examples/driving_audio_4.wav --pretrained_clip_DINet_path=./asserts/clip_training_DINet_256mouth.pth
# The result in ./asserts/inference_result
# Out:
# /content/DINet
# Arguments: Namespace(chin_extension=20, chin_width=50, driving_audio_path='./asserts/examples/driving_audio_4.wav', mouth_region_size=256, pretrained_clip_DINet_path='./asserts/clip_training_DINet_256mouth.pth', side_point_drop=10, source_openface_landmark_path='/content/kimk_7s_raw.csv', source_video_path='/content/kimk_7s_raw.mp4')
# Unknown Arguments: []
# Chin Width: 50
# Chin Extension: 20
# Side Point Drop: 10
# extracting frames from video: /content/kimk_7s_raw.mp4
# warning: the input video is not 25 fps, it would be better to trans it to 25 fps!
# extracting deepspeech feature from : ./asserts/examples/driving_audio_4.wav
# /content/DINet/utils/deep_speech.py:71: UserWarning: Audio has multiple channels, the first channel is used
#   "Audio has multiple channels, the first channel is used")
# 2025-01-23 06:23:18.299967: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2025-01-23 06:23:18.304272: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2025-01-23 06:23:18.304455: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f025a54920 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-01-23 06:23:18.304492: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-01-23 06:23:18.360364: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2025-01-23 06:23:18.524430: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2025-01-23 06:23:18.775784: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2025-01-23 06:23:18.918792: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2025-01-23 06:23:19.061391: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# loading facial landmarks from : /content/kimk_7s_raw.csv
# aligning frames with driving audio
# selecting five reference images
# Namespace(audio_channel=29, chin_extension=10, chin_width=50, deepspeech_model_path='./asserts/output_graph.pb', driving_audio_path='./asserts/examples/driving_audio_4.wav', mouth_region_size=256, pretrained_clip_DINet_path='./asserts/clip_training_DINet_256mouth.pth', ref_channel=15, res_video_dir='./asserts/inference_result', side_point_drop=5, source_channel=3, source_openface_landmark_path='/content/kimk_7s_raw.csv', source_video_path='/content/kimk_7s_raw.mp4')
# Traceback (most recent call last):
#   File "inference.py", line 108, in <module>
#     raise ('our method cannot handle videos with large changes in facial size!')
# TypeError: exceptions must derive from BaseException

# %%
#@title Custom Inference
# Use OpenFace_2.2.0_win_x64 to generate a CSV file for your own video.
# %cd /content/DINet
# !gdown https://drive.google.com/uc\?id\=1flufnx3tIZZLja2XsxPEBcwqI_IUZFNG
# !unzip input.zip
# !rm input.zip
# !python inference.py --mouth_region_size=256 --source_video_path=./input/888.mp4 --source_openface_landmark_path=./input/888.csv --driving_audio_path=./input/888.wav --pretrained_clip_DINet_path=./asserts/clip_training_DINet_256mouth.pth
# The result in ./asserts/inference_result
# Out:
# /content/DINet
# Downloading...
# From: https://drive.google.com/uc?id=1flufnx3tIZZLja2XsxPEBcwqI_IUZFNG
# To: /content/DINet/input.zip
# 100% 1.03M/1.03M [00:00<00:00, 125MB/s]
# Archive:  input.zip
#    creating: input/
#   inflating: input/888.csv
#   inflating: input/888.mp4
#   inflating: input/888.wav
# extracting frames from video: ./input/888.mp4
# warning: the input video is not 25 fps, it would be better to trans it to 25 fps!
# extracting deepspeech feature from : ./input/888.wav
# /content/DINet/utils/deep_speech.py:71: UserWarning: Audio has multiple channels, the first channel is used
#   "Audio has multiple channels, the first channel is used")
# 2023-08-06 18:44:39.568383: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2023-08-06 18:44:39.574888: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2023-08-06 18:44:39.575055: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56a311679770 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-08-06 18:44:39.575085: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-08-06 18:44:39.619555: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2023-08-06 18:44:39.828173: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2023-08-06 18:44:40.124003: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2023-08-06 18:44:40.284872: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# 2023-08-06 18:44:40.454860: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 201326592 exceeds 10% of system memory.
# loading facial landmarks from : ./input/888.csv
# aligning frames with driving audio
# selecting five reference images
# loading pretrained model from: ./asserts/clip_training_DINet_256mouth.pth
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# synthesizing 0/149 frame
# /usr/local/lib/python3.7/site-packages/torch/nn/functional.py:3385: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# synthesizing 1/149 frame
# synthesizing 2/149 frame
# synthesizing 3/149 frame
# synthesizing 4/149 frame
# synthesizing 5/149 frame
# synthesizing 6/149 frame
# synthesizing 7/149 frame
# synthesizing 8/149 frame
# synthesizing 9/149 frame
# synthesizing 10/149 frame
# synthesizing 11/149 frame
# synthesizing 12/149 frame
# synthesizing 13/149 frame
# synthesizing 14/149 frame
# synthesizing 15/149 frame
# synthesizing 16/149 frame
# synthesizing 17/149 frame
# synthesizing 18/149 frame
# synthesizing 19/149 frame
# synthesizing 20/149 frame
# synthesizing 21/149 frame
# synthesizing 22/149 frame
# synthesizing 23/149 frame
# synthesizing 24/149 frame
# synthesizing 25/149 frame
# synthesizing 26/149 frame
# synthesizing 27/149 frame
# synthesizing 28/149 frame
# synthesizing 29/149 frame
# synthesizing 30/149 frame
# synthesizing 31/149 frame
# synthesizing 32/149 frame
# synthesizing 33/149 frame
# synthesizing 34/149 frame
# synthesizing 35/149 frame
# synthesizing 36/149 frame
# synthesizing 37/149 frame
# synthesizing 38/149 frame
# synthesizing 39/149 frame
# synthesizing 40/149 frame
# synthesizing 41/149 frame
# synthesizing 42/149 frame
# synthesizing 43/149 frame
# synthesizing 44/149 frame
# synthesizing 45/149 frame
# synthesizing 46/149 frame
# synthesizing 47/149 frame
# synthesizing 48/149 frame
# synthesizing 49/149 frame
# synthesizing 50/149 frame
# synthesizing 51/149 frame
# synthesizing 52/149 frame
# synthesizing 53/149 frame
# synthesizing 54/149 frame
# synthesizing 55/149 frame
# synthesizing 56/149 frame
# synthesizing 57/149 frame
# synthesizing 58/149 frame
# synthesizing 59/149 frame
# synthesizing 60/149 frame
# synthesizing 61/149 frame
# synthesizing 62/149 frame
# synthesizing 63/149 frame
# synthesizing 64/149 frame
# synthesizing 65/149 frame
# synthesizing 66/149 frame
# synthesizing 67/149 frame
# synthesizing 68/149 frame
# synthesizing 69/149 frame
# synthesizing 70/149 frame
# synthesizing 71/149 frame
# synthesizing 72/149 frame
# synthesizing 73/149 frame
# synthesizing 74/149 frame
# synthesizing 75/149 frame
# synthesizing 76/149 frame
# synthesizing 77/149 frame
# synthesizing 78/149 frame
# synthesizing 79/149 frame
# synthesizing 80/149 frame
# synthesizing 81/149 frame
# synthesizing 82/149 frame
# synthesizing 83/149 frame
# synthesizing 84/149 frame
# synthesizing 85/149 frame
# synthesizing 86/149 frame
# synthesizing 87/149 frame
# synthesizing 88/149 frame
# synthesizing 89/149 frame
# synthesizing 90/149 frame
# synthesizing 91/149 frame
# synthesizing 92/149 frame
# synthesizing 93/149 frame
# synthesizing 94/149 frame
# synthesizing 95/149 frame
# synthesizing 96/149 frame
# synthesizing 97/149 frame
# synthesizing 98/149 frame
# synthesizing 99/149 frame
# synthesizing 100/149 frame
# synthesizing 101/149 frame
# synthesizing 102/149 frame
# synthesizing 103/149 frame
# synthesizing 104/149 frame
# synthesizing 105/149 frame
# synthesizing 106/149 frame
# synthesizing 107/149 frame
# synthesizing 108/149 frame
# synthesizing 109/149 frame
# synthesizing 110/149 frame
# synthesizing 111/149 frame
# synthesizing 112/149 frame
# synthesizing 113/149 frame
# synthesizing 114/149 frame
# synthesizing 115/149 frame
# synthesizing 116/149 frame
# synthesizing 117/149 frame
# synthesizing 118/149 frame
# synthesizing 119/149 frame
# synthesizing 120/149 frame
# synthesizing 121/149 frame
# synthesizing 122/149 frame
# synthesizing 123/149 frame
# synthesizing 124/149 frame
# synthesizing 125/149 frame
# synthesizing 126/149 frame
# synthesizing 127/149 frame
# synthesizing 128/149 frame
# synthesizing 129/149 frame
# synthesizing 130/149 frame
# synthesizing 131/149 frame
# synthesizing 132/149 frame
# synthesizing 133/149 frame
# synthesizing 134/149 frame
# synthesizing 135/149 frame
# synthesizing 136/149 frame
# synthesizing 137/149 frame
# synthesizing 138/149 frame
# synthesizing 139/149 frame
# synthesizing 140/149 frame
# synthesizing 141/149 frame
# synthesizing 142/149 frame
# synthesizing 143/149 frame
# synthesizing 144/149 frame
# synthesizing 145/149 frame
# synthesizing 146/149 frame
# synthesizing 147/149 frame
# synthesizing 148/149 frame
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './asserts/inference_result/888_facial_dubbing.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:05.96, start: 0.000000, bitrate: 587 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 496x640 [SAR 1:1 DAR 31:40], 585 kb/s, 25 fps, 25 tbr, 12800 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from './input/888.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:00:06.01, bitrate: 1411 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to './asserts/inference_result/888_facial_dubbing_add_audio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 496x640 [SAR 1:1 DAR 31:40], q=2-31, 585 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=  149 fps=0.0 q=-1.0 Lsize=     523kB time=00:00:05.99 bitrate= 715.4kbits/s speed=28.7x
# video:426kB audio:92kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.004367%
# [aac @ 0x567cbb754680] Qavg: 5442.436
